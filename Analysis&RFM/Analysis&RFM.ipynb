# %%
! pip install rfm
# Out:
# Collecting rfm
#   Downloading rfm-1.0.9-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from rfm) (1.5.3)
# Requirement already satisfied: numpy>=1.20.1 in /usr/local/lib/python3.10/dist-packages (from rfm) (1.23.5)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from rfm) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->rfm) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->rfm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->rfm) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->rfm) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->rfm) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->rfm) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->rfm) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->rfm) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->rfm) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->rfm) (1.16.0)
# Installing collected packages: rfm
# Successfully installed rfm-1.0.9

# %%
import pandas as pd
import plotly.graph_objects as go
from rfm import RFM

# %%
df = pd.read_excel("/content/Online Retail.xlsx")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
for column in df.columns:
    if df[column].dtype == 'object':
      df[column] = df[column].astype('category')

# %%
df['revenue'] = df['Quantity'] * df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  revenue
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34

# %% [markdown]
# # **RFM**

# %%
r = RFM(df,customer_id="CustomerID",transaction_date="InvoiceDate",amount="revenue")
rfm_dataframe = pd.DataFrame(r.rfm_table)

# %%
rfm_dataframe.head()
# Out:
#   CustomerID  recency  frequency  monetary_value  r  f  m rfm_score    segment
# 0      15039        9       1483        19637.76  5  5  5       555  Champions
# 1      17735        1        690        13109.06  5  5  5       555  Champions
# 2      16549        9        925         4033.58  5  5  5       555  Champions
# 3      15218       10        166         5756.81  5  5  5       555  Champions
# 4      13767        1        399        16942.31  5  5  5       555  Champions

# %%
total_customers = len(rfm_dataframe)

freq_more_than_500 = len(rfm_dataframe[rfm_dataframe['frequency'] > 500])
freq_less_than_50 = len(rfm_dataframe[rfm_dataframe['frequency'] < 50])
freq_between_500_and_50 = len(rfm_dataframe[(rfm_dataframe['frequency'] > 50) & (rfm_dataframe['frequency'] < 500)])


percentage_more_than_500 = (freq_more_than_500 / total_customers) * 100
percentage_less_than_50 = (freq_less_than_50 / total_customers) * 100
percentage_between_500_and_50 = (freq_between_500_and_50 / total_customers) * 100

print("Customers with frequency more than 500:", freq_more_than_500, f"({percentage_more_than_500:.2f}%)")
print("Customers with frequency less than 50:", freq_less_than_50, f"({percentage_less_than_50:.2f}%)")
print("Customers with frequency between 500 and 50:", freq_between_500_and_50, f"({percentage_between_500_and_50:.2f}%)")
# Out:
# Customers with frequency more than 500: 81 (1.85%)
# Customers with frequency less than 50: 2434 (55.67%)
# Customers with frequency between 500 and 50: 1836 (41.99%)

# %%
filtered_data = rfm_dataframe[rfm_dataframe['frequency'] > 1]

fig = go.Figure()

fig.add_trace(go.Histogram(x=filtered_data['recency'], nbinsx=20,
                            marker_color='skyblue', opacity=0.7,
                            text=filtered_data['frequency'],
                            textposition="outside",
                            textfont_color='black'))

fig.update_layout(
    title='Distribution of Recency for Returning Customers (More than 1 Purchase)',
    xaxis_title='Recency',
    yaxis_title='Frequency',
    bargap=0.05,
    xaxis=dict(tickfont=dict(color='black'), linecolor='black'),
    yaxis=dict(tickfont=dict(color='black'), linecolor='black'),
    title_font=dict(color='black')
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="